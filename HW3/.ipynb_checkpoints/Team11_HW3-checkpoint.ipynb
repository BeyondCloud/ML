# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os
import tensorflow as tf

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

reset_graph()

# %%
# load data: digits 5 to 9, but still label with 0 to 4, 
# because TensorFlow expects label's integers from 0 to n_classes-1.
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")

X_train2_full = mnist.train.images[mnist.train.labels >= 5]
y_train2_full = mnist.train.labels[mnist.train.labels >= 5] - 5
X_valid2_full = mnist.validation.images[mnist.validation.labels >= 5]
y_valid2_full = mnist.validation.labels[mnist.validation.labels >= 5] - 5
X_test2 = mnist.test.images[mnist.test.labels >= 5]
y_test2 = mnist.test.labels[mnist.test.labels >= 5] - 5
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# we want to keep only 100 instances per class in the training set 
# and let's keep only 30 instances per class in the validation set
# tesing set is already loaded above
def sample_n_instances_per_class(X, y, n=100):
    Xs, ys = [], []
    for label in np.unique(y):
        idx = (y == label)
        Xc = X[idx][:n]
        yc = y[idx][:n]
        Xs.append(Xc)
        ys.append(yc)
    return np.concatenate(Xs), np.concatenate(ys)

X_train2, y_train2 = sample_n_instances_per_class(X_train2_full, y_train2_full, n=100)
X_valid2, y_valid2 = sample_n_instances_per_class(X_valid2_full, y_valid2_full, n=30)

# %%
#restore HW2 model's tensor by name

tf.reset_default_graph()
restore_saver = tf.train.import_meta_graph( "./model/Team11_HW2.ckpt.meta")
X = tf.get_default_graph().get_tensor_by_name("X:0")
y = tf.get_default_graph().get_tensor_by_name("y:0")
loss = tf.get_default_graph().get_tensor_by_name("loss:0")
Y_proba = tf.get_default_graph().get_tensor_by_name("Y_proba:0")
logits = Y_proba.op.inputs[0]
accuracy = tf.get_default_graph().get_tensor_by_name("accuracy:0")

#specify trainable variable,this will freeze 1~5 layers and train the output layer only
output_layer_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="logits")
learning_rate = 0.01
optimizer = tf.train.AdamOptimizer(learning_rate, name="Adam2")
training_op = optimizer.minimize(loss, var_list=output_layer_vars)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

init = tf.global_variables_initializer()
five_frozen_saver = tf.train.Saver()

# %% [markdown]
# HW3.1 soft max only

# %%
import time

n_epochs = 1000
#if loss didn't improve 20 epochs consecutive,early stop occur
early_stop_trigger_step = 20
early_stop_cnt = 0
batch_size = 30

with tf.Session() as sess:
    init.run()
    restore_saver.restore(sess, "./model/Team11_HW2.ckpt")
    
    #initialize softmax layer
    for var in output_layer_vars:
        var.initializer.run()
    
    best_loss = np.infty
    
    t0 = time.time()
    for epoch in range(n_epochs):
        
        #random select training data
        rnd_idx = np.random.permutation(len(X_train2)) #create 1~500 rnd
        for rnd_indices in np.array_split(rnd_idx, len(X_train2) // batch_size):
            X_batch, y_batch = X_train2[rnd_indices], y_train2[rnd_indices]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
            
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: X_valid2, y: y_valid2})
        
        if loss_val < best_loss:
            early_stop_cnt = 0
            best_loss = loss_val
            save_path = five_frozen_saver.save(sess, "./Team11_HW3_1.ckpt")
        else:
            early_stop_cnt += 1
            if early_stop_cnt > early_stop_trigger_step:
                print("Early stop triggered")
                break
        print("{}\tValid loss: {:.4f}\tBest loss: {:.4f}\tACC: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

    t1 = time.time()
    print("Training time: {:.1f}sec".format(t1 - t0))

with tf.Session() as sess:
    five_frozen_saver.restore(sess, "./Team11_HW3_1.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_test2, y: y_test2})
    print("test acc: {:.2f}%".format(acc_test * 100))
# Out:
# INFO:tensorflow:Restoring parameters from ./model/Team11_HW2.ckpt
# 0	Valid loss: 15.6580	Best loss: 15.6580	ACC: 8.00%
# 1	Valid loss: 12.6536	Best loss: 12.6536	ACC: 8.00%
# 2	Valid loss: 8.8642	Best loss: 8.8642	ACC: 9.33%
# 3	Valid loss: 6.3263	Best loss: 6.3263	ACC: 10.67%
# 4	Valid loss: 3.7347	Best loss: 3.7347	ACC: 11.33%
# 5	Valid loss: 2.2184	Best loss: 2.2184	ACC: 32.00%
# 6	Valid loss: 1.4932	Best loss: 1.4932	ACC: 43.33%
# 7	Valid loss: 1.3058	Best loss: 1.3058	ACC: 50.00%
# 8	Valid loss: 1.4664	Best loss: 1.3058	ACC: 44.00%
# 9	Valid loss: 1.3992	Best loss: 1.3058	ACC: 49.33%
# 10	Valid loss: 1.3318	Best loss: 1.3058	ACC: 49.33%
# 11	Valid loss: 1.4148	Best loss: 1.3058	ACC: 44.67%
# 12	Valid loss: 1.3337	Best loss: 1.3058	ACC: 46.00%
# 13	Valid loss: 1.3658	Best loss: 1.3058	ACC: 40.00%
# 14	Valid loss: 1.2451	Best loss: 1.2451	ACC: 50.00%
# 15	Valid loss: 1.2783	Best loss: 1.2451	ACC: 44.67%
# 16	Valid loss: 1.3349	Best loss: 1.2451	ACC: 45.33%
# 17	Valid loss: 1.2985	Best loss: 1.2451	ACC: 54.67%
# 18	Valid loss: 1.3325	Best loss: 1.2451	ACC: 45.33%
# 19	Valid loss: 1.2760	Best loss: 1.2451	ACC: 46.67%
# 20	Valid loss: 1.3212	Best loss: 1.2451	ACC: 45.33%
# 21	Valid loss: 1.3899	Best loss: 1.2451	ACC: 49.33%
# 22	Valid loss: 1.2455	Best loss: 1.2451	ACC: 50.67%
# 23	Valid loss: 1.2787	Best loss: 1.2451	ACC: 47.33%
# 24	Valid loss: 1.2269	Best loss: 1.2269	ACC: 52.00%
# 25	Valid loss: 1.2276	Best loss: 1.2269	ACC: 50.00%
# 26	Valid loss: 1.2723	Best loss: 1.2269	ACC: 45.33%
# 27	Valid loss: 1.3166	Best loss: 1.2269	ACC: 44.67%
# 28	Valid loss: 1.2561	Best loss: 1.2269	ACC: 48.00%
# 29	Valid loss: 1.2239	Best loss: 1.2239	ACC: 54.00%
# 30	Valid loss: 1.2607	Best loss: 1.2239	ACC: 50.67%
# 31	Valid loss: 1.2861	Best loss: 1.2239	ACC: 42.00%
# 32	Valid loss: 1.2203	Best loss: 1.2203	ACC: 50.00%
# 33	Valid loss: 1.2641	Best loss: 1.2203	ACC: 47.33%
# 34	Valid loss: 1.1927	Best loss: 1.1927	ACC: 52.00%
# 35	Valid loss: 1.2353	Best loss: 1.1927	ACC: 47.33%
# 36	Valid loss: 1.2476	Best loss: 1.1927	ACC: 47.33%
# 37	Valid loss: 1.2422	Best loss: 1.1927	ACC: 46.67%
# 38	Valid loss: 1.2695	Best loss: 1.1927	ACC: 42.67%
# 39	Valid loss: 1.2338	Best loss: 1.1927	ACC: 50.67%
# 40	Valid loss: 1.2177	Best loss: 1.1927	ACC: 52.67%
# 41	Valid loss: 1.2896	Best loss: 1.1927	ACC: 54.00%
# 42	Valid loss: 1.2433	Best loss: 1.1927	ACC: 51.33%
# 43	Valid loss: 1.2105	Best loss: 1.1927	ACC: 50.00%
# 44	Valid loss: 1.2341	Best loss: 1.1927	ACC: 45.33%
# 45	Valid loss: 1.3015	Best loss: 1.1927	ACC: 48.67%
# 46	Valid loss: 1.2723	Best loss: 1.1927	ACC: 50.67%
# 47	Valid loss: 1.2028	Best loss: 1.1927	ACC: 52.00%
# 48	Valid loss: 1.2540	Best loss: 1.1927	ACC: 48.00%
# 49	Valid loss: 1.1956	Best loss: 1.1927	ACC: 52.00%
# 50	Valid loss: 1.2399	Best loss: 1.1927	ACC: 48.67%
# 51	Valid loss: 1.2473	Best loss: 1.1927	ACC: 44.67%
# 52	Valid loss: 1.2461	Best loss: 1.1927	ACC: 47.33%
# 53	Valid loss: 1.1856	Best loss: 1.1856	ACC: 44.00%
# 54	Valid loss: 1.2336	Best loss: 1.1856	ACC: 49.33%
# 55	Valid loss: 1.2770	Best loss: 1.1856	ACC: 48.00%
# 56	Valid loss: 1.2266	Best loss: 1.1856	ACC: 51.33%
# 57	Valid loss: 1.2048	Best loss: 1.1856	ACC: 48.00%
# 58	Valid loss: 1.2145	Best loss: 1.1856	ACC: 54.67%
# 59	Valid loss: 1.3281	Best loss: 1.1856	ACC: 38.67%
# 60	Valid loss: 1.1934	Best loss: 1.1856	ACC: 53.33%
# 61	Valid loss: 1.2035	Best loss: 1.1856	ACC: 47.33%
# 62	Valid loss: 1.2379	Best loss: 1.1856	ACC: 46.67%
# 63	Valid loss: 1.1930	Best loss: 1.1856	ACC: 50.00%
# 64	Valid loss: 1.2171	Best loss: 1.1856	ACC: 50.67%
# 65	Valid loss: 1.3151	Best loss: 1.1856	ACC: 50.67%
# 66	Valid loss: 1.3610	Best loss: 1.1856	ACC: 41.33%
# 67	Valid loss: 1.2766	Best loss: 1.1856	ACC: 50.67%
# 68	Valid loss: 1.2321	Best loss: 1.1856	ACC: 50.67%
# 69	Valid loss: 1.3048	Best loss: 1.1856	ACC: 42.00%
# 70	Valid loss: 1.1760	Best loss: 1.1760	ACC: 54.00%
# 71	Valid loss: 1.1941	Best loss: 1.1760	ACC: 48.00%
# 72	Valid loss: 1.2305	Best loss: 1.1760	ACC: 46.00%
# 73	Valid loss: 1.1788	Best loss: 1.1760	ACC: 55.33%
# 74	Valid loss: 1.2712	Best loss: 1.1760	ACC: 49.33%
# 75	Valid loss: 1.3047	Best loss: 1.1760	ACC: 48.67%
# 76	Valid loss: 1.2887	Best loss: 1.1760	ACC: 40.00%
# 77	Valid loss: 1.1937	Best loss: 1.1760	ACC: 51.33%
# 78	Valid loss: 1.1977	Best loss: 1.1760	ACC: 54.00%
# 79	Valid loss: 1.2388	Best loss: 1.1760	ACC: 50.67%
# 80	Valid loss: 1.2940	Best loss: 1.1760	ACC: 44.00%
# 81	Valid loss: 1.2850	Best loss: 1.1760	ACC: 47.33%
# 82	Valid loss: 1.1697	Best loss: 1.1697	ACC: 51.33%
# 83	Valid loss: 1.1795	Best loss: 1.1697	ACC: 48.67%
# 84	Valid loss: 1.2188	Best loss: 1.1697	ACC: 56.00%
# 85	Valid loss: 1.2759	Best loss: 1.1697	ACC: 46.00%
# 86	Valid loss: 1.2080	Best loss: 1.1697	ACC: 50.67%
# 87	Valid loss: 1.1933	Best loss: 1.1697	ACC: 50.67%
# 88	Valid loss: 1.2101	Best loss: 1.1697	ACC: 43.33%
# 89	Valid loss: 1.2094	Best loss: 1.1697	ACC: 50.00%
# 90	Valid loss: 1.2296	Best loss: 1.1697	ACC: 54.00%
# 91	Valid loss: 1.2459	Best loss: 1.1697	ACC: 46.67%
# 92	Valid loss: 1.2229	Best loss: 1.1697	ACC: 55.33%
# 93	Valid loss: 1.2284	Best loss: 1.1697	ACC: 47.33%
# 94	Valid loss: 1.2589	Best loss: 1.1697	ACC: 46.67%
# 95	Valid loss: 1.2678	Best loss: 1.1697	ACC: 46.00%
# 96	Valid loss: 1.3090	Best loss: 1.1697	ACC: 44.67%
# 97	Valid loss: 1.2164	Best loss: 1.1697	ACC: 47.33%
# 98	Valid loss: 1.3070	Best loss: 1.1697	ACC: 44.67%
# 99	Valid loss: 1.1750	Best loss: 1.1697	ACC: 48.67%
# 100	Valid loss: 1.3100	Best loss: 1.1697	ACC: 46.67%
# 101	Valid loss: 1.2588	Best loss: 1.1697	ACC: 47.33%
# 102	Valid loss: 1.1935	Best loss: 1.1697	ACC: 50.00%
# Early stop triggered
# Training time: 45.0sec
# INFO:tensorflow:Restoring parameters from ./Team11_HW3_1.ckpt
# test acc: 47.69%

# %% [markdown]
# HW3.2 cache 5th layer's output

# %%
hidden5_out = tf.get_default_graph().get_tensor_by_name("hidden5_out:0")

n_epochs = 1000
early_stop_trigger_step = 20
early_stop_cnt = 0
batch_size = 30

with tf.Session() as sess:
    init.run()
    restore_saver.restore(sess, "./model/Team11_HW2.ckpt")
    for var in output_layer_vars:
        var.initializer.run()

    #cache 5th layer
    hidden5_train = hidden5_out.eval(feed_dict={X: X_train2, y: y_train2})
    hidden5_valid = hidden5_out.eval(feed_dict={X: X_valid2, y: y_valid2})
    best_loss = np.infty
    t0 = time.time()
    
    for epoch in range(n_epochs):
        rnd_idx = np.random.permutation(len(X_train2)) 
        for rnd_indices in np.array_split(rnd_idx, len(X_train2) // batch_size):
            h5_batch, y_batch = hidden5_train[rnd_indices], y_train2[rnd_indices]
            sess.run(training_op, feed_dict={hidden5_out: h5_batch, y: y_batch})
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={hidden5_out: hidden5_valid, y: y_valid2})
        if loss_val < best_loss:
            save_path = five_frozen_saver.save(sess, "./Team11_HW3_2.ckpt")
            best_loss = loss_val
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1
            if early_stop_cnt > early_stop_trigger_step:
                print("Early stop triggered")
                break
        print("{}\tValid loss: {:.4f}\tBest loss: {:.4f}\tACC: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

    t1 = time.time()
    print("Training time: {:.1f}sec".format(t1 - t0))

with tf.Session() as sess:
    five_frozen_saver.restore(sess, "./Team11_HW3_2.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_test2, y: y_test2})
    print("test acc: {:.2f}%".format(acc_test * 100))
# Out:
# INFO:tensorflow:Restoring parameters from ./model/Team11_HW2.ckpt
# 0	Valid loss: 15.6321	Best loss: 15.6321	ACC: 8.00%
# 1	Valid loss: 12.1778	Best loss: 12.1778	ACC: 9.33%
# 2	Valid loss: 9.2077	Best loss: 9.2077	ACC: 9.33%
# 3	Valid loss: 6.5272	Best loss: 6.5272	ACC: 10.00%
# 4	Valid loss: 4.1321	Best loss: 4.1321	ACC: 12.67%
# 5	Valid loss: 2.6545	Best loss: 2.6545	ACC: 24.67%
# 6	Valid loss: 1.8441	Best loss: 1.8441	ACC: 34.67%
# 7	Valid loss: 1.6498	Best loss: 1.6498	ACC: 36.67%
# 8	Valid loss: 1.6024	Best loss: 1.6024	ACC: 38.67%
# 9	Valid loss: 1.5565	Best loss: 1.5565	ACC: 42.00%
# 10	Valid loss: 1.5296	Best loss: 1.5296	ACC: 42.67%
# 11	Valid loss: 1.5225	Best loss: 1.5225	ACC: 40.67%
# 12	Valid loss: 1.5089	Best loss: 1.5089	ACC: 41.33%
# 13	Valid loss: 1.4831	Best loss: 1.4831	ACC: 42.67%
# 14	Valid loss: 1.4664	Best loss: 1.4664	ACC: 42.67%
# 15	Valid loss: 1.4459	Best loss: 1.4459	ACC: 44.00%
# 16	Valid loss: 1.4400	Best loss: 1.4400	ACC: 43.33%
# 17	Valid loss: 1.4252	Best loss: 1.4252	ACC: 44.67%
# 18	Valid loss: 1.4183	Best loss: 1.4183	ACC: 44.67%
# 19	Valid loss: 1.4133	Best loss: 1.4133	ACC: 46.67%
# 20	Valid loss: 1.3860	Best loss: 1.3860	ACC: 45.33%
# 21	Valid loss: 1.3719	Best loss: 1.3719	ACC: 45.33%
# 22	Valid loss: 1.3783	Best loss: 1.3719	ACC: 46.00%
# 23	Valid loss: 1.3812	Best loss: 1.3719	ACC: 44.00%
# 24	Valid loss: 1.3581	Best loss: 1.3581	ACC: 48.00%
# 25	Valid loss: 1.3494	Best loss: 1.3494	ACC: 46.67%
# 26	Valid loss: 1.3409	Best loss: 1.3409	ACC: 51.33%
# 27	Valid loss: 1.3577	Best loss: 1.3409	ACC: 47.33%
# 28	Valid loss: 1.3416	Best loss: 1.3409	ACC: 47.33%
# 29	Valid loss: 1.3235	Best loss: 1.3235	ACC: 48.67%
# 30	Valid loss: 1.3328	Best loss: 1.3235	ACC: 50.67%
# 31	Valid loss: 1.3197	Best loss: 1.3197	ACC: 50.00%
# 32	Valid loss: 1.3084	Best loss: 1.3084	ACC: 49.33%
# 33	Valid loss: 1.3217	Best loss: 1.3084	ACC: 48.67%
# 34	Valid loss: 1.3003	Best loss: 1.3003	ACC: 50.67%
# 35	Valid loss: 1.2996	Best loss: 1.2996	ACC: 48.67%
# 36	Valid loss: 1.3084	Best loss: 1.2996	ACC: 50.00%
# 37	Valid loss: 1.3229	Best loss: 1.2996	ACC: 48.67%
# 38	Valid loss: 1.2938	Best loss: 1.2938	ACC: 48.00%
# 39	Valid loss: 1.2941	Best loss: 1.2938	ACC: 47.33%
# 40	Valid loss: 1.3072	Best loss: 1.2938	ACC: 54.00%
# 41	Valid loss: 1.2908	Best loss: 1.2908	ACC: 50.00%
# 42	Valid loss: 1.2885	Best loss: 1.2885	ACC: 50.00%
# 43	Valid loss: 1.2829	Best loss: 1.2829	ACC: 52.00%
# 44	Valid loss: 1.2831	Best loss: 1.2829	ACC: 50.67%
# 45	Valid loss: 1.2700	Best loss: 1.2700	ACC: 50.67%
# 46	Valid loss: 1.3040	Best loss: 1.2700	ACC: 52.67%
# 47	Valid loss: 1.2817	Best loss: 1.2700	ACC: 51.33%
# 48	Valid loss: 1.2889	Best loss: 1.2700	ACC: 49.33%
# 49	Valid loss: 1.2751	Best loss: 1.2700	ACC: 51.33%
# 50	Valid loss: 1.2810	Best loss: 1.2700	ACC: 50.00%
# 51	Valid loss: 1.2754	Best loss: 1.2700	ACC: 50.67%
# 52	Valid loss: 1.2686	Best loss: 1.2686	ACC: 52.67%
# 53	Valid loss: 1.2855	Best loss: 1.2686	ACC: 52.00%
# 54	Valid loss: 1.2834	Best loss: 1.2686	ACC: 51.33%
# 55	Valid loss: 1.2826	Best loss: 1.2686	ACC: 53.33%
# 56	Valid loss: 1.2756	Best loss: 1.2686	ACC: 49.33%
# 57	Valid loss: 1.2893	Best loss: 1.2686	ACC: 52.00%
# 58	Valid loss: 1.2806	Best loss: 1.2686	ACC: 48.67%
# 59	Valid loss: 1.2723	Best loss: 1.2686	ACC: 51.33%
# 60	Valid loss: 1.2844	Best loss: 1.2686	ACC: 53.33%
# 61	Valid loss: 1.2790	Best loss: 1.2686	ACC: 50.00%
# 62	Valid loss: 1.2946	Best loss: 1.2686	ACC: 53.33%
# 63	Valid loss: 1.2701	Best loss: 1.2686	ACC: 51.33%
# 64	Valid loss: 1.2803	Best loss: 1.2686	ACC: 53.33%
# 65	Valid loss: 1.2739	Best loss: 1.2686	ACC: 52.00%
# 66	Valid loss: 1.2690	Best loss: 1.2686	ACC: 49.33%
# 67	Valid loss: 1.2687	Best loss: 1.2686	ACC: 50.67%
# 68	Valid loss: 1.2881	Best loss: 1.2686	ACC: 50.67%
# 69	Valid loss: 1.2797	Best loss: 1.2686	ACC: 51.33%
# 70	Valid loss: 1.2771	Best loss: 1.2686	ACC: 52.00%
# 71	Valid loss: 1.2746	Best loss: 1.2686	ACC: 54.00%
# 72	Valid loss: 1.2704	Best loss: 1.2686	ACC: 50.00%
# Early stop triggered
# Training time: 76.4sec
# INFO:tensorflow:Restoring parameters from ./Team11_HW3_2.ckpt
# test acc: 47.48%

# %% [markdown]
# HW3.3 Load HW2 model again, now use 4th hidden layer's output and feed them into new softmax layer:

# %%
reset_graph()

n_outputs = 5

restore_saver = tf.train.import_meta_graph("./model/Team11_HW2.ckpt.meta")
he_init = tf.contrib.layers.variance_scaling_initializer()
X = tf.get_default_graph().get_tensor_by_name("X:0")
y = tf.get_default_graph().get_tensor_by_name("y:0")

#here we connect 4th hidden layer output to softmax layer
hidden4_out = tf.get_default_graph().get_tensor_by_name("hidden4_out:0")
logits = tf.layers.dense(hidden4_out, n_outputs, kernel_initializer=he_init, name="new_logits")
Y_proba = tf.nn.softmax(logits)
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)

#define optimizer and loss function
loss = tf.reduce_mean(xentropy)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")
output_layer_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="new_logits")
learning_rate = 0.01
optimizer = tf.train.AdamOptimizer(learning_rate, name="Adam2")
training_op = optimizer.minimize(loss, var_list=output_layer_vars)

init = tf.global_variables_initializer()
four_frozen_saver = tf.train.Saver()

# %%
n_epochs = 1000
batch_size = 30

early_stop_trigger_step = 20
early_stop_cnt = 0
best_loss = np.infty

with tf.Session() as sess:
    init.run()
    restore_saver.restore(sess, "./model/Team11_HW2.ckpt")
        
    for epoch in range(n_epochs):
        rnd_idx = np.random.permutation(len(X_train2))
        for rnd_indices in np.array_split(rnd_idx, len(X_train2) // batch_size):
            X_batch, y_batch = X_train2[rnd_indices], y_train2[rnd_indices]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: X_valid2, y: y_valid2})
        if loss_val < best_loss:
            save_path = four_frozen_saver.save(sess, "./Team11_HW3_3.ckpt")
            best_loss = loss_val
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1
            if early_stop_cnt > early_stop_trigger_step:
                print("Early stop triggered")
                break
        print("{}\tValidation loss: {:.6f}\tBest loss: {:.6f}\tAccuracy: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

with tf.Session() as sess:
    four_frozen_saver.restore(sess, "./Team11_HW3_3.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_test2, y: y_test2})
    print("Final test accuracy: {:.2f}%".format(acc_test * 100))
# Out:
# INFO:tensorflow:Restoring parameters from ./model/Team11_HW2.ckpt
# 0	Validation loss: 3.133135	Best loss: 3.133135	Accuracy: 44.00%
# 1	Validation loss: 2.350898	Best loss: 2.350898	Accuracy: 44.00%
# 2	Validation loss: 2.064627	Best loss: 2.064627	Accuracy: 34.00%
# 3	Validation loss: 2.552538	Best loss: 2.064627	Accuracy: 47.33%
# 4	Validation loss: 2.335384	Best loss: 2.064627	Accuracy: 30.00%
# 5	Validation loss: 2.001016	Best loss: 2.001016	Accuracy: 44.00%
# 6	Validation loss: 1.633297	Best loss: 1.633297	Accuracy: 42.67%
# 7	Validation loss: 1.681264	Best loss: 1.633297	Accuracy: 49.33%
# 8	Validation loss: 1.913101	Best loss: 1.633297	Accuracy: 48.67%
# 9	Validation loss: 2.223051	Best loss: 1.633297	Accuracy: 48.00%
# 10	Validation loss: 1.949555	Best loss: 1.633297	Accuracy: 44.67%
# 11	Validation loss: 1.692915	Best loss: 1.633297	Accuracy: 43.33%
# 12	Validation loss: 1.848531	Best loss: 1.633297	Accuracy: 38.67%
# 13	Validation loss: 1.807144	Best loss: 1.633297	Accuracy: 48.67%
# 14	Validation loss: 1.974199	Best loss: 1.633297	Accuracy: 46.00%
# 15	Validation loss: 1.901647	Best loss: 1.633297	Accuracy: 52.67%
# 16	Validation loss: 1.989292	Best loss: 1.633297	Accuracy: 39.33%
# 17	Validation loss: 2.164274	Best loss: 1.633297	Accuracy: 40.00%
# 18	Validation loss: 1.833176	Best loss: 1.633297	Accuracy: 43.33%
# 19	Validation loss: 1.451626	Best loss: 1.451626	Accuracy: 51.33%
# 20	Validation loss: 1.718518	Best loss: 1.451626	Accuracy: 52.00%
# 21	Validation loss: 1.473670	Best loss: 1.451626	Accuracy: 42.67%
# 22	Validation loss: 1.752000	Best loss: 1.451626	Accuracy: 37.33%
# 23	Validation loss: 1.940001	Best loss: 1.451626	Accuracy: 36.67%
# 24	Validation loss: 1.763099	Best loss: 1.451626	Accuracy: 41.33%
# 25	Validation loss: 1.816323	Best loss: 1.451626	Accuracy: 38.67%
# 26	Validation loss: 2.010914	Best loss: 1.451626	Accuracy: 41.33%
# 27	Validation loss: 1.823970	Best loss: 1.451626	Accuracy: 40.67%
# 28	Validation loss: 2.061333	Best loss: 1.451626	Accuracy: 50.67%
# 29	Validation loss: 1.735709	Best loss: 1.451626	Accuracy: 44.67%
# 30	Validation loss: 1.766521	Best loss: 1.451626	Accuracy: 41.33%
# 31	Validation loss: 1.573442	Best loss: 1.451626	Accuracy: 49.33%
# 32	Validation loss: 1.698114	Best loss: 1.451626	Accuracy: 46.67%
# 33	Validation loss: 1.706469	Best loss: 1.451626	Accuracy: 51.33%
# 34	Validation loss: 1.418781	Best loss: 1.418781	Accuracy: 46.67%
# 35	Validation loss: 1.410839	Best loss: 1.410839	Accuracy: 46.00%
# 36	Validation loss: 1.740389	Best loss: 1.410839	Accuracy: 46.00%
# 37	Validation loss: 2.340435	Best loss: 1.410839	Accuracy: 43.33%
# 38	Validation loss: 1.548075	Best loss: 1.410839	Accuracy: 52.67%
# 39	Validation loss: 1.718781	Best loss: 1.410839	Accuracy: 47.33%
# 40	Validation loss: 1.579576	Best loss: 1.410839	Accuracy: 48.67%
# 41	Validation loss: 1.661283	Best loss: 1.410839	Accuracy: 44.00%
# 42	Validation loss: 1.514843	Best loss: 1.410839	Accuracy: 40.67%
# 43	Validation loss: 1.985317	Best loss: 1.410839	Accuracy: 36.67%
# 44	Validation loss: 1.511179	Best loss: 1.410839	Accuracy: 42.67%
# 45	Validation loss: 1.949219	Best loss: 1.410839	Accuracy: 44.67%
# 46	Validation loss: 1.457071	Best loss: 1.410839	Accuracy: 57.33%
# 47	Validation loss: 1.266939	Best loss: 1.266939	Accuracy: 52.67%
# 48	Validation loss: 1.845413	Best loss: 1.266939	Accuracy: 43.33%
# 49	Validation loss: 1.687329	Best loss: 1.266939	Accuracy: 44.67%
# 50	Validation loss: 1.609672	Best loss: 1.266939	Accuracy: 49.33%
# 51	Validation loss: 1.852692	Best loss: 1.266939	Accuracy: 38.67%
# 52	Validation loss: 1.688205	Best loss: 1.266939	Accuracy: 48.67%
# 53	Validation loss: 1.532373	Best loss: 1.266939	Accuracy: 50.00%
# 54	Validation loss: 2.114554	Best loss: 1.266939	Accuracy: 46.00%
# 55	Validation loss: 1.788568	Best loss: 1.266939	Accuracy: 44.67%
# 56	Validation loss: 1.551311	Best loss: 1.266939	Accuracy: 49.33%
# 57	Validation loss: 1.674552	Best loss: 1.266939	Accuracy: 48.00%
# 58	Validation loss: 1.690895	Best loss: 1.266939	Accuracy: 50.00%
# 59	Validation loss: 2.294697	Best loss: 1.266939	Accuracy: 40.67%
# 60	Validation loss: 1.660295	Best loss: 1.266939	Accuracy: 48.67%
# 61	Validation loss: 1.343226	Best loss: 1.266939	Accuracy: 52.00%
# 62	Validation loss: 1.719891	Best loss: 1.266939	Accuracy: 38.00%
# 63	Validation loss: 1.420509	Best loss: 1.266939	Accuracy: 48.67%
# 64	Validation loss: 2.225469	Best loss: 1.266939	Accuracy: 42.00%
# 65	Validation loss: 1.592595	Best loss: 1.266939	Accuracy: 56.67%
# 66	Validation loss: 1.821322	Best loss: 1.266939	Accuracy: 44.00%
# 67	Validation loss: 1.479875	Best loss: 1.266939	Accuracy: 48.67%
# Early stop triggered
# INFO:tensorflow:Restoring parameters from ./Team11_HW3_3.ckpt
# Final test accuracy: 48.82%

# %% [markdown]
# HW3.4  Unfreeze top 2 layers

# %%
learning_rate = 0.01
unfrozen_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="hidden[34]|new_logits")
optimizer = tf.train.AdamOptimizer(learning_rate, name="Adam3")
training_op = optimizer.minimize(loss, var_list=unfrozen_vars)

init = tf.global_variables_initializer()
two_frozen_saver = tf.train.Saver()

# %%
n_epochs = 1000
batch_size = 30

  
early_stop_trigger_step = 20
early_stop_cnt = 0


with tf.Session() as sess:
    init.run()
    four_frozen_saver.restore(sess, "./Team11_HW3_3.ckpt")
    best_loss = np.infty
    for epoch in range(n_epochs):
        rnd_idx = np.random.permutation(len(X_train2))
        for rnd_indices in np.array_split(rnd_idx, len(X_train2) // batch_size):
            X_batch, y_batch = X_train2[rnd_indices], y_train2[rnd_indices]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: X_valid2, y: y_valid2})
        if loss_val < best_loss:
            save_path = two_frozen_saver.save(sess, "./Team11_HW3_4.ckpt")
            best_loss = loss_val
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1
            if early_stop_cnt > early_stop_trigger_step:
                print("Early stop triggered")
                break
        print("{}\tValidation loss: {:.6f}\tBest loss: {:.6f}\tAccuracy: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

with tf.Session() as sess:
    two_frozen_saver.restore(sess, "./Team11_HW3_4.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_test2, y: y_test2})
    print("Final test accuracy: {:.2f}%".format(acc_test * 100))
# Out:
# INFO:tensorflow:Restoring parameters from ./Team11_HW3_3.ckpt
# 0	Validation loss: 1.960130	Best loss: 1.960130	Accuracy: 46.67%
# 1	Validation loss: 1.950920	Best loss: 1.950920	Accuracy: 35.33%
# 2	Validation loss: 1.490337	Best loss: 1.490337	Accuracy: 52.00%
# 3	Validation loss: 1.371305	Best loss: 1.371305	Accuracy: 48.00%
# 4	Validation loss: 1.259536	Best loss: 1.259536	Accuracy: 54.67%
# 5	Validation loss: 1.252204	Best loss: 1.252204	Accuracy: 48.00%
# 6	Validation loss: 1.262321	Best loss: 1.252204	Accuracy: 54.00%
# 7	Validation loss: 1.258616	Best loss: 1.252204	Accuracy: 50.67%
# 8	Validation loss: 1.271679	Best loss: 1.252204	Accuracy: 48.00%
# 9	Validation loss: 1.203111	Best loss: 1.203111	Accuracy: 56.00%
# 10	Validation loss: 1.162395	Best loss: 1.162395	Accuracy: 49.33%
# 11	Validation loss: 1.004879	Best loss: 1.004879	Accuracy: 63.33%
# 12	Validation loss: 1.206293	Best loss: 1.004879	Accuracy: 55.33%
# 13	Validation loss: 1.238659	Best loss: 1.004879	Accuracy: 53.33%
# 14	Validation loss: 1.112963	Best loss: 1.004879	Accuracy: 55.33%
# 15	Validation loss: 1.120144	Best loss: 1.004879	Accuracy: 56.00%
# 16	Validation loss: 1.128441	Best loss: 1.004879	Accuracy: 56.67%
# 17	Validation loss: 1.141903	Best loss: 1.004879	Accuracy: 54.67%
# 18	Validation loss: 1.168775	Best loss: 1.004879	Accuracy: 56.00%
# 19	Validation loss: 1.052740	Best loss: 1.004879	Accuracy: 60.00%
# 20	Validation loss: 1.189942	Best loss: 1.004879	Accuracy: 57.33%
# 21	Validation loss: 1.119838	Best loss: 1.004879	Accuracy: 57.33%
# 22	Validation loss: 1.075615	Best loss: 1.004879	Accuracy: 59.33%
# 23	Validation loss: 1.186627	Best loss: 1.004879	Accuracy: 50.00%
# 24	Validation loss: 1.158142	Best loss: 1.004879	Accuracy: 50.67%
# 25	Validation loss: 1.178998	Best loss: 1.004879	Accuracy: 49.33%
# 26	Validation loss: 1.147074	Best loss: 1.004879	Accuracy: 58.00%
# 27	Validation loss: 1.166808	Best loss: 1.004879	Accuracy: 55.33%
# 28	Validation loss: 1.235280	Best loss: 1.004879	Accuracy: 52.67%
# 29	Validation loss: 1.108532	Best loss: 1.004879	Accuracy: 54.67%
# 30	Validation loss: 1.205776	Best loss: 1.004879	Accuracy: 53.33%
# 31	Validation loss: 1.164167	Best loss: 1.004879	Accuracy: 56.00%
# Early stop triggered
# INFO:tensorflow:Restoring parameters from ./Team11_HW3_4.ckpt
# Final test accuracy: 50.26%
